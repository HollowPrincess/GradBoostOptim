# %%
#imports:
import pandas as pd
import numpy as np
import math
from time import time

from sklearn.utils import shuffle

import xgboost

from scipy.stats import randint as sp_randint # int distribution for random search
from scipy.stats import uniform # float distribution for random search
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from matplotlib import pyplot as plt

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# TensorFlow 2.x selected.
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive 
drive.mount('/mntDrive') 
data=pd.read_csv("/mntDrive/My Drive/НИР магистратура/Оптимизация гиперпараметров алгоритмов градиентного бустинга/Практика/data/input/prepared_facebook_data.csv")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /mntDrive

# %%
# grid search
# get some data
X, y = data.iloc[:,:-1].values, data.iloc[:,-1].values

# build a classifier
clf = xgboost.XGBRegressor(verbosity=0)

# use a full grid over 4 parameters
param_grid = {'max_depth': [2, 5, 8], 'min_child_weight': [2, 5, 8]}

# %%
# run grid search
grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False)
start = time()
grid_search.fit(X, y)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 319.19 seconds for 9 candidate parameter settings.

# %%
# run grid search
with tf.device('/device:GPU:0'):
    grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False)
    start = time()
    grid_search.fit(X, y)

    print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 317.26 seconds for 9 candidate parameter settings.

# %%
# run grid search

grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False, n_jobs=-1)
start = time()
grid_search.fit(X, y)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 284.68 seconds for 9 candidate parameter settings.

# %%
# run grid search
with tf.device('/device:GPU:0'):
    grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False, n_jobs=-1)
    start = time()
    grid_search.fit(X, y)

    print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 295.23 seconds for 9 candidate parameter settings.

# %%
clf = xgboost.XGBRegressor(tree_method = "gpu_hist", gpu_id=0, verbosity=0)

# run grid search
grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False)
start = time()
grid_search.fit(X,y)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 23.86 seconds for 9 candidate parameter settings.

# %%
clf = xgboost.XGBRegressor(tree_method = "gpu_hist", gpu_id=0, verbosity=0)

# run grid search
grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False, n_jobs=-1)
start = time()
grid_search.fit(X,y)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 33.70 seconds for 9 candidate parameter settings.

# %%
# run grid search
with tf.device('/device:GPU:0'):
    grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False)
    start = time()
    grid_search.fit(X,y)

    print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 23.60 seconds for 9 candidate parameter settings.

# %%
# run grid search
with tf.device('/device:GPU:0'):
    grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring="r2" ,iid=False, n_jobs=-1)
    start = time()
    grid_search.fit(X,y)

    print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))
# Out:
# GridSearchCV took 33.98 seconds for 9 candidate parameter settings.
